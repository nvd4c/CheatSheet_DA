# %% [markdown]
# # Seaborn

# %% [markdown]
# #The Python visualization library Seaborn is based on
# matplotlib and provides a high-level interface for drawing
# attractive statistical graphics.
# Make use of the following aliases to import the libraries:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #The basic steps to creating plots with Seaborn are:
#  1. Prepare some data
#  2. Control figure aesthetics
#  3. Plot with Seaborn
#  4. Further customize your plot

# %%
tips = sns.load_dataset("tips")                  # step 1 prepare some data
sns.set_style("whitegrid")                       # step 2 Control figure aesthetics
g = sns.lmplot(x="tip", y="total_bill", data=tips, aspect=2)    # step 3 Plot some Seaborn
g = (g.set_axis_labels("Tip","Total bill(USD)").set(xlim=(0,10),ylim=(0,100)))
plt.title("title")                         # step 4 Further customize your plot
plt.show(g)

# %% [markdown]
# # 1. Data

# %%
import pandas as pd
import numpy as np
uniform_data = np.random.rand(10, 12)
data = pd.DataFrame({'x':np.arange(1,101), 'y':np.random.normal(0,4,100)})

# %% [markdown]
# #Seaborn also offers built-in data sets:

# %%
titanic = sns.load_dataset("titanic")
iris = sns.load_dataset("iris")

# %% [markdown]
# # 2. Figure Aesthetics

# %%
f, ax = plt.subplots(figsize(5,6)) # Create a figure and one subplot
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-1e25646da4a5> in <module>
# ----> 1 f, ax = plt.subplots(figsize(5,6)) # Create a figure and one subplot
#
# NameError: name 'figsize' is not defined

# %% [markdown]
# # 2.1 Seaborn Styles

# %%
sns.set                       # (Re)set a seaborn default
sns.set_style("whitegrid")    # set the matplotlib parameters
sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})  # set the matplotlib parameters
sns.axes_style("whiregrid")  # return a dict of params or use with to temporarily set the style
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-5f44258121a6> in <module>
#       2 sns.set_style("whitegrid")    # set the matplotlib parameters
#       3 sns.set_style("ticks", {"xtick.major.size":8, "ytick.major.size":8})  # set the matplotlib parameters
# ----> 4 sns.axes_style("whiregrid")  # return a dict of params or use with to temporarily set the style
#
# ~\anaconda3\lib\site-packages\seaborn\rcmod.py in axes_style(style, rc)
#     181         styles = ["white", "dark", "whitegrid", "darkgrid", "ticks"]
#     182         if style not in styles:
# --> 183             raise ValueError("style must be one of %s" % ", ".join(styles))
#     184
#     185         # Define colors here
#
# ValueError: style must be one of white, dark, whitegrid, darkgrid, ticks

# %% [markdown]
# # 2.2 Context Functions

# %%
sns.set_context("talk")    # Set context to "talk"
sns.set_context("notebook", font_scale=1.5,rc={"lines.linewidth":2.5})   #Set context to "notebook" Scale font elements
# and override param mapping

# %% [markdown]
# # 2.3 Color Palette

# %%
sns.set_palette("husl",3) # Define the color palette
sns.color_palette("husl") # Use with with to temporarily set palette
flatui = ["#9b59b6","#3498db","#95a5a6","#e74c3c","#34495e","#2ecc71"]
sns.set_palette(flatui)   # Set your own color palette

# %% [markdown]
# # 3. Plotting With Seaborn

# %% [markdown]
# # 3.1 Axis Grids

# %%
g = sns.FacetGrid(titanic, col="survived", row="sex")            # Subplot grid for plotting conditional elationships

# %%
 g = g.map(plt.hist,"age")

# %%
sns.factorplot(x="pclass",y="survived",  hue="sex", data=titanic)        #Draw a categorical plot onto a Facetgrid
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.lmplot(x="sepal_width", y="sepal_length", ue="species", data=iris)      
# Plot data and regression model fits across a FacetGrid
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a3be4337597a> in <module>
# ----> 1 sns.lmplot(x="sepal_width", y="sepal_length", ue="species", data=iris)
#       2 # Plot data and regression model fits across a FacetGrid
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: lmplot() got an unexpected keyword argument 'ue'

# %%
h = sns.PairGrid(iris)                     #Subplot grid for plotting pairwise
h = h.map(plt.scatter)                     #relationships
sns.pairplot(iris)                         #Plot pairwise bivariate distributions
i = sns.JointGrid(x="x", y="y",vdata=data) #Grid for bivariate plot with marginal univariate plots 
                 
i = i.plot(sns.regplot, sns.distplot)
sns.jointplot("sepal_length", "sepal_width", data=iris, kind='kde')             #Plot bivariate distribution
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-284ee5a273ad> in <module>
#       2 h = h.map(plt.scatter)                     #relationships
#       3 sns.pairplot(iris)                         #Plot pairwise bivariate distributions
# ----> 4 i = sns.JointGrid(x="x", y="y",vdata=data) #Grid for bivariate plot with marginal univariate plots
#       5
#       6 i = i.plot(sns.regplot, sns.distplot)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# TypeError: __init__() got an unexpected keyword argument 'vdata'

# %% [markdown]
# # 3.2 Categorical Plots

# %% [markdown]
# # 3.2.1 Scatterplot

# %%
sns.stripplot(x="species", y="petal_length",cdata=iris)        # Scatterplot with one categorical variable
            
sns.swarmplot(x="species",vy="petal_length", data=iris)        # Categorical scatterplot with non-overlapping points
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-758cd117c141> in <module>
# ----> 1 sns.stripplot(x="species", y="petal_length",cdata=iris)        # Scatterplot with one categorical variable
#       2
#       3 sns.swarmplot(x="species",vy="petal_length", data=iris)        # Categorical scatterplot with non-overlapping points
#       4
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2792         warnings.warn(msg, UserWarning)
#    2793
# ...

# %% [markdown]
# # 3.2.2 Bar Chart

# %%
sns.barplot(x="sex",y="survived", hue="class", data=titanic)    
# Show point estimates and confidence intervals with scatterplot glyphs
# Out:
#   File "<ipython-input-19-3a30a65cd7e6>", line 2
#     sns.barplot(x="sex",                     # Show point estimates and confidence intervals with scatterplot glyphs
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # 3.2.3 Count Plot

# %%
sns.countplot(x="deck", sns.countplot(x="deck", palette="Greens_d")                 # Show count of observations
# Out:
#   File "<ipython-input-20-b186ecd31934>", line 4
#     palette="Greens_d")
#                        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# # 3.2.4 Point Plot

# %%
sns.pointplot(x="class", y="survived", hue="sex", data=titanic, palette={"male":"g","female":"m"}, markers=["^","o"],
              linestyles=["-","--"])
#Show point estimates and confidence intervals as rectangular bars
# Out:
# <AxesSubplot:xlabel='class', ylabel='survived'>

# %% [markdown]
# # 3.2.5 Boxplot

# %%
sns.boxplot(x="alive", y="age", hue="adult_male", data=titanic) #boxplot
sns.boxplot(data=iris,orient="h")  #Boxplot with wide-form data
# Out:
# <AxesSubplot:xlabel='alive', ylabel='age'>

# %% [markdown]
# # 3.2.6 Violinplot

# %%
sns.violinplot(x="age",y="sex", hue="survived", data=titanic)  #Violin plot
# Out:
# <AxesSubplot:xlabel='age', ylabel='sex'>

# %% [markdown]
# # 3.3 Regression Plots

# %%
sns.regplot(x="sepal_width", y="sepal_length", data=iris, ax=ax)
#Plot data and a linear regression model fit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-407e94081864> in <module>
# ----> 1 sns.regplot(x="sepal_width", y="sepal_length", data=iris, ax=ax)
#       2 #Plot data and a linear regression model fit
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # 3.4 Distribution Plots

# %%
plot = sns.distplot(data.y, kde=False, color="b")
#Plot univariate distribution
# Out:
# C:\Users\A\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # 3.5 Matrix Plots

# %%
sns.heatmap(uniform_data,vmin=0,vmax=1) #Heatmap

# %% [markdown]
# # 4. Further Customizations

# %% [markdown]
# # 4.1 Axisgrid Objects

# %%
g.despine(left=True)                       #Remove left spine 
g.set_ylabels("Survived")                  #Set the labels of the y-axis
g.set_xticklabels(rotation=45)                # Set the tick labels for x
g.set_axis_labels("Survived", "Sex")         #Set the axis labels
h.set(xlim=(0,5), ylim=(0,5), xticks=[0,2.5,5], yticks=[0,2.5,5]) #Set the limit and ticks of the x-and y-axis

# %% [markdown]
# # 4.2 Plot

# %%
plt.title("A Title")     #Add plot title
plt.ylabel("Survived")   #Adjust the label of the y-axis
plt.ylabel("Survived")   #Adjust the label of the x-axis
plt.ylim(0,100)            #Adjust the limits of the y-axis
plt.xlim(0,10)            #Adjust the limits of the x-axis
plt.setp(ax,yticks=[0,5]) #Adjust a plot property
plt.tight_layout()       #Adjust subplot params
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-13671aefad98> in <module>
#       5 plt.ylim(0,100)            #Adjust the limits of the y-axis
#       6 plt.xlim(0,10)            #Adjust the limits of the x-axis
# ----> 7 plt.setp(ax,yticks=[0,5]) #Adjust a plot property
#       8 plt.tight_layout()       #Adjust subplot params
#
# NameError: name 'ax' is not defined

# %% [markdown]
# # 5. Show or Save Plot

# %%
plt.show()                              #Show the plot
plt.savefig("foo.png")                    #Show the plot as a figure
plt.savefig("foo.png",transparent=True)   #Save transparent figure

# %% [markdown]
# # Close & Clear

# %%
plt.cla()       #Clear an axis
plt.clf()        #Clear an entire figure
plt.close()    #Close a window
